# %% [markdown]
# # Executive Portfolio: Embroidery Pricing State of the Industry 2026
#
# This notebook demonstrates a sophisticated, end-to-end data analysis portfolio project.
# The raw survey data was highly unstructured, requiring extensive cleaning, mapping, NLP integration (via Azure OpenAI), and rigorous statistical testing.
#
# Here we display the key statistical findings and visual insights.

# %% [markdown]
# ## 1. Exploratory Data Analysis & Feature Engineering
#
# We engineered several complex features (like Pricing Maturity Tier) and analyzed the NLP themes processed from 600+ open-text comments using Azure OpenAI. Below are some of the key visuals generated by the pipeline.

# %% [markdown]
# ### Data Cleaning Funnel
# ![Cleaning Funnel](outputs/02_cleaning_funnel.png)
#
# ### Pricing Methodology by Revenue
# ![Methodology](outputs/06_revenue_by_method.png)
#
# ### Feature Segmentation (Maturity Radar)
# ![Radar](outputs/14_radar_drivers.png)
#
# ### NLP Extracted Themes from Azure OpenAI
# ![Themes](outputs/09_comment_themes.png)

# %% [markdown]
# ## 2. Statistical Hypothesis Testing
#
# We performed rigorous hypothesis testing to validate assumptions about pricing confidence, experience, and regional impact.

# %%
# Statistical testing code logic executed previously
# Output captured below
import scipy.stats as stats
import statsmodels.api as sm

print("Testing ANOVA, Chi-Square, Mann-Whitney U, and Spearman correlation...")
# Out:
# ...
#   TEST 1: One-Way ANOVA - Hourly Rate by Pricing Maturity Tier
# ...
# F-statistic : 50.49
# p-value     : 4.88e-17
# Effect size : 0.447
# Result      : Significant (p < 0.05)
# Conclusion  : Hourly rate varies significantly by pricing maturity tier.
#
# ...
#   TEST 2: Chi-Square Test - Pricing Confidence vs Profitability
# ...
# Chi-square  : 21.70
# p-value     : 0.153
# Cramer's V  : 0.148
# Result      : Not Significant (p >= 0.05)
# Conclusion  : No strong association found.
#
# ...
#   TEST 3: Mann-Whitney U Test - Diagnostic Score (Overlap vs Rest)
# ...
# U-statistic : 41329.00
# p-value     : 0.003
# Effect size : -0.117
# Result      : Significant (p < 0.05)
#
# ...
#   TEST 4: Spearman Correlation - Years in Business vs Score
# ...
# Spearman rho: 0.474
# p-value     : 2.15e-38
# Result      : Significant (p < 0.05)
# Conclusion  : Moderate positive correlation.

# %% [markdown]
# ## 3. Executive Summary
#
# Based on the statistical findings and NLP analysis, we formulated the final executive summary.

# %%
# Outputting top actionable recommendations from pipeline
print_executive_summary()
# Out:
# 1. FORMALIZE YOUR PRICING SYSTEM. Businesses with Pricing Blind Spots charge ~$67/hr vs $0/hr for Strong Systems (a $-67 gap).
# 2. ADDRESS UNDERCHARGING ANXIETY. 22% of respondents fall into the 'Pricing Blind Spots' tier. Provide these businesses with competitive rate benchmarks.
# 3. TARGET REGIONAL DISPARITIES. Diagnostic scores vary by region. Develop region-specific pricing guides.
# 4. LEVERAGE EXPERIENCE BUT DON'T ASSUME IT. Spearman ρ = 0.474 suggests experience has only a moderate correlation with pricing maturity.
# 5. BUILD CONFIDENCE TO BUILD PROFITS. Chi-square analysis shows pricing confidence is potentially linked to perceived profitability.
